# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

import sklearn
import sklearn.metrics as metrics

from sklearn.linear_model import LinearRegression, LassoCV, RidgeCV, Ridge, Lasso, ElasticNet
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split, cross_val_score, KFold
from sklearn.preprocessing import StandardScaler, PolynomialFeatures

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Read Data

# %%
train_cleaned = pd.read_csv('../data/train_cleaned.csv', index_col='Id')
test_cleaned = pd.read_csv('../data/test_cleaned.csv', index_col='Id')

# %% [markdown]
# ## Baseline Regression Model

# %%
# Train data

X_train = train_cleaned.drop(['SalePrice', 'PID'], axis=1).copy()
y_train = train_cleaned[['SalePrice']].copy()

# Test data

X_test = test_cleaned.drop(['PID'], axis=1).copy()

# %%
X_train.columns
# Out:
# Index(['MS SubClass', 'MS Zoning', 'Lot Frontage', 'Lot Area', 'Street',
#        'Alley', 'Lot Shape', 'Land Contour', 'Utilities', 'Lot Config',
#        'Land Slope', 'Neighborhood', 'Condition 1', 'Condition 2', 'Bldg Type',
#        'House Style', 'Overall Qual', 'Overall Cond', 'Year Built',
#        'Year Remod/Add', 'Roof Style', 'Roof Matl', 'Exterior 1st',
#        'Exterior 2nd', 'Mas Vnr Type', 'Mas Vnr Area', 'Exter Qual',
#        'Exter Cond', 'Foundation', 'Bsmt Qual', 'Bsmt Cond', 'Bsmt Exposure',
#        'BsmtFin Type 1', 'BsmtFin SF 1', 'BsmtFin Type 2', 'BsmtFin SF 2',
#        'Bsmt Unf SF', 'Total Bsmt SF', 'Heating', 'Heating QC', 'Central Air',
#        'Electrical', '1st Flr SF', '2nd Flr SF', 'Low Qual Fin SF',
#        'Gr Liv Area', 'Bsmt Full Bath', 'Bsmt Half Bath', 'Full Bath',
#        'Half Bath', 'Bedroom AbvGr', 'Kitchen AbvGr', 'Kitchen Qual',
#        'TotRms AbvGrd', 'Functional', 'Fireplaces', 'Fireplace Qu',
#        'Garage Type', 'Garage Yr Blt', 'Garage Finish', 'Garage Cars',
#        'Garage Area', 'Garage Qual', 'Garage Cond', 'Paved Drive',
#        'Wood Deck SF', 'Open Porch SF', 'Enclosed Porch', '3Ssn Porch',
#        'Screen Porch', 'Pool Area', 'Pool QC', 'Fence', 'Misc Feature',
#        'Misc Val', 'Mo Sold', 'Yr Sold', 'Sale Type'],
#       dtype='object')

# %%
X_test.columns
# Out:
# Index(['MS SubClass', 'MS Zoning', 'Lot Frontage', 'Lot Area', 'Street',
#        'Alley', 'Lot Shape', 'Land Contour', 'Utilities', 'Lot Config',
#        'Land Slope', 'Neighborhood', 'Condition 1', 'Condition 2', 'Bldg Type',
#        'House Style', 'Overall Qual', 'Overall Cond', 'Year Built',
#        'Year Remod/Add', 'Roof Style', 'Roof Matl', 'Exterior 1st',
#        'Exterior 2nd', 'Mas Vnr Type', 'Mas Vnr Area', 'Exter Qual',
#        'Exter Cond', 'Foundation', 'Bsmt Qual', 'Bsmt Cond', 'Bsmt Exposure',
#        'BsmtFin Type 1', 'BsmtFin SF 1', 'BsmtFin Type 2', 'BsmtFin SF 2',
#        'Bsmt Unf SF', 'Total Bsmt SF', 'Heating', 'Heating QC', 'Central Air',
#        'Electrical', '1st Flr SF', '2nd Flr SF', 'Low Qual Fin SF',
#        'Gr Liv Area', 'Bsmt Full Bath', 'Bsmt Half Bath', 'Full Bath',
#        'Half Bath', 'Bedroom AbvGr', 'Kitchen AbvGr', 'Kitchen Qual',
#        'TotRms AbvGrd', 'Functional', 'Fireplaces', 'Fireplace Qu',
#        'Garage Type', 'Garage Yr Blt', 'Garage Finish', 'Garage Cars',
#        'Garage Area', 'Garage Qual', 'Garage Cond', 'Paved Drive',
#        'Wood Deck SF', 'Open Porch SF', 'Enclosed Porch', '3Ssn Porch',
#        'Screen Porch', 'Pool Area', 'Pool QC', 'Fence', 'Misc Feature',
#        'Misc Val', 'Mo Sold', 'Yr Sold', 'Sale Type'],
#       dtype='object')

# %%
nominal_features = ['PID', 'MS SubClass', 'MS Zoning', 'Street', 'Alley', 'Land Contour', 'Lot Config',
                    'Neighborhood', 'Condition 1', 'Condition 2', 'Bldg Type', 'House Style', 'Roof Style',
                    'Roof Matl', 'Exterior 1st', 'Exterior 2nd', 'Mas Vnr Type', 'Foundation', 'Heating',
                    'Central Air', 'Garage Type', 'Misc Feature', 'Sale Type']

# %%
# Take all nominal features except PID
reduced_nominal_features = nominal_features[1:]

# %% [markdown]
# **Get dummies of train dataset**

# %%
X_train = pd.get_dummies(X_train, columns=reduced_nominal_features, drop_first=True)

# %% [markdown]
# **Get dummies of test dataset**

# %%
X_test = pd.get_dummies(X_test, columns=reduced_nominal_features, drop_first=False)

# %% [markdown]
# **Ensure that the number of columns in the train and test datasets are identical and in the same order**

# %%
def handle_unequal_train_test_columns(X_train, X_test):
    columns_not_in_test = list(set(X_train.columns).difference(set(X_test.columns)))
    for col in columns_not_in_test:
        X_test[col] = 0
        
    columns_not_in_train = list(set(X_test.columns).difference(set(X_train.columns)))
    X_test.drop(columns_not_in_train, axis=1, inplace=True)
    return X_train[sorted(X_train.columns)], X_test[sorted(X_test.columns)]

# %%
X_train, X_test = handle_unequal_train_test_columns(X_train, X_test)

# %%
X_test.columns == X_train.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True])

# %%
X_test.shape
# Out:
# (879, 210)

# %%
X_train.shape
# Out:
# (2026, 210)

# %%
linreg = LinearRegression()

# %%
linreg.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# linreg.coef_

# %%
y_train_pred = linreg.predict(X_train)

# %%
def r2_adj(y_true, y_preds, p):
    n = len(y_true)
    y_mean = np.mean(y_true)
    numerator = np.sum(np.square(y_true - y_preds)) / (n - p - 1)
    denominator = np.sum(np.square(y_true - y_mean)) / (n - 1)
    return (1 - (numerator / denominator)).values[0]

# %%
def get_regression_metrics(y_true, y_pred, p):
    mse = metrics.mean_squared_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    msle = metrics.mean_squared_log_error(y_true, y_pred)
    mae = metrics.median_absolute_error(y_true, y_pred)
    r2 = metrics.r2_score(y_true, y_pred)
    r2a = r2_adj(y_true, y_pred, p)
    
    print('Mean squared error      = ', mse)
    print('Root mean squared error = ', rmse)
    print('Mean squared log error  = ', msle)
    print('Median absolute error   = ', mae)
    print('R^2                     = ', r2)
    print('Adjusted R^2            = ', r2a)
    
    return {
        'mse': mse,
        'rmse': rmse,
        'msle': msle,
        'mae': mae,
        'r2': r2,
        'r2_adjusted': r2a
    }

# %%
regression_metrics = get_regression_metrics(y_train, y_train_pred, X_train.shape[1])
# Out:
# Mean squared error      =  428765086.14449865
# Root mean squared error =  20706.64352676451
# Mean squared log error  =  0.023043740531227326
# Median absolute error   =  11005.477029263973
# R^2                     =  0.931460678672341
# Adjusted R^2            =  0.9235305092625291

# %%
regression_metrics['rmse']
# Out:
# 20706.64352676451

# %%
scores = cross_val_score(linreg, X_train, y_train, cv=5)
scores.mean()
# Out:
# -103820173019.25813

# %%
X_test_indices = X_test.index

# %%
y_test_pred = linreg.predict(X_test)

# %%
linreg.coef_
# Out:
# array([[ 7.83176203e+07,  7.83176192e+07,  6.60647776e+00,
#          1.51490847e+03, -4.89866770e+03, -3.80844582e+03,
#          2.51371724e+04, -4.62133823e+12, -6.26655138e+02,
#          4.90109107e+03, -3.88612996e+03,  4.11750591e+03,
#          3.48847028e+03,  3.18340965e+02,  2.63953900e+03,
#         -2.53332963e+13, -2.53332963e+13, -2.53332963e+13,
#         -2.59389106e+02,  6.09928755e+02, -4.11067813e+03,
#          1.85496867e+04, -9.99711932e+03, -1.59551330e+04,
#         -7.85656844e+03, -1.63909876e+04, -8.85354557e+03,
#          3.33631802e+04, -1.41166741e+04, -1.38592622e+04,
#          1.17723083e+01,  5.28874160e+03,  7.59113926e+03,
#          8.08520996e+02, -5.45152407e+11,  2.29043004e+03,
#          6.34566581e+05,  6.67282862e+05,  6.24313443e+05,
#          6.41711506e+05,  6.72200608e+05, -8.28765221e+03,
#         -1.68918793e+04, -3.46825498e+03, -4.30802870e+04,
#         -1.46382198e+04,  1.46112016e+04,  3.67411134e+04,
#          1.32230154e+04,  5.69717222e+03,  1.66707961e+03,
#          1.87136060e+04,  2.15176800e+04,  5.11691541e+03,
#          5.45152407e+11,  3.94559855e+03,  1.56755065e+03,
#          2.53332963e+13,  2.69613047e+04,  9.51873779e+00,
#          3.55218278e+02,  3.97517433e+01, -3.67149676e+02]])

# %%
y_test_pred = [i[0] for i in y_test_pred.tolist()]

# %%
def make_and_get_submissions_file(X_test_indices, y_test_pred, file_name):
    submissions = pd.DataFrame({'Id': X_test_indices, 'SalePrice': y_test_pred})
    submissions.set_index('Id', inplace=True)
    submissions.sort_index(inplace=True)
    submissions.to_csv('../data/{}.csv'.format(file_name))
    
    return submissions

# %%
submissions = make_and_get_submissions_file(X_test_indices, y_test_pred, 'submissions_baseline_regression')

# %%
submissions
# Out:
#           SalePrice
# Id
# 2     127953.388219
# 4     275385.601952
# 6     184550.823195
# 7     240920.847028
# 17    228578.250702
# ...             ...
# 2919   68525.781325
# 2921   78695.781325
# 2922  187571.093152
# 2925  186255.299023
# 2928  129435.175503
#
# [879 rows x 1 columns]

# %%
submissions[submissions['SalePrice'] < 0]
# Out:
#           SalePrice
# Id
# 1908 -479561.588145
# 2766 -465502.157446

# %% [markdown]
# ## Scaling and Regularization

# %%
# Train data

X_train = train_cleaned.drop(['SalePrice', 'PID'], axis=1).copy()
y_train = train_cleaned[['SalePrice']].copy()

# Test data
X_test = test_cleaned.drop(['PID'], axis=1).copy()

# %%
nominal_features = ['PID', 'MS SubClass', 'MS Zoning', 'Street', 'Alley', 'Land Contour', 'Lot Config',
                    'Neighborhood', 'Condition 1', 'Condition 2', 'Bldg Type', 'House Style', 'Roof Style',
                    'Roof Matl', 'Exterior 1st', 'Exterior 2nd', 'Mas Vnr Type', 'Foundation', 'Heating',
                    'Central Air', 'Garage Type', 'Misc Feature', 'Sale Type']

# %%
# Take all nominal features except PID
reduced_nominal_features = nominal_features[1:]

# %% [markdown]
# **Get dummies for ordinal features**

# %%
X_train = pd.get_dummies(X_train, columns=reduced_nominal_features, drop_first=True)

# %%
X_test = pd.get_dummies(X_test, columns=reduced_nominal_features, drop_first=False)

# %%
X_train, X_test = handle_unequal_train_test_columns(X_train, X_test)
X_train_columns = X_train.columns
X_test_columns = X_test.columns

# %% [markdown]
# **Standardization of features**

# %%
ss = StandardScaler()
ss.fit(X_train)
X_train = ss.transform(X_train)
X_test = ss.transform(X_test)

# %% [markdown]
# **Lasso Regression with All Features**

# %%
# Cross Validation
optimal_lasso = LassoCV(n_alphas=500, cv=10) # uses 10-fold

# %%
# Model Fitting and Evaluation
optimal_lasso.fit(X_train, y_train)

lasso = Lasso(alpha=optimal_lasso.alpha_)
lasso.fit(X_train, y_train)

lasso_scores = cross_val_score(lasso, X_train, y_train, cv=10)
lasso_scores.mean()
# Out:
# 0.8499490834480177

# %%
(-cross_val_score(lasso, X_train, y_train, cv=10, scoring='neg_root_mean_squared_error')).mean()
# Out:
# 29516.41034682917

# %%
y_test_pred = lasso.predict(X_test)

# %%
submissions = make_and_get_submissions_file(X_test_indices, y_test_pred, 'submissions_lasso_regression_all_features')

# %%
plt.figure(figsize=(10, 8))
plt.stem(lasso.coef_)
# Out:
# <StemContainer object of 3 artists>

# %%
(lasso.coef_ != 0).nonzero()[0]
# Out:
# array([  0,   3,   7,   8,   9,  10,  11,  12,  14,  16,  17,  18,  22,
#         23,  24,  25,  31,  39,  42,  44,  45,  50,  52,  59,  64,  67,
#         69,  70,  72,  76,  77,  78,  79,  81,  84,  88,  90,  91,  92,
#         95,  98, 103, 104, 105, 106, 107, 110, 111, 118, 119, 120, 122,
#        132, 134, 138, 139, 140, 142, 143, 145, 146, 148, 152, 155, 156,
#        159, 164, 165, 166, 167, 168, 169, 172, 173, 174, 178, 179, 181,
#        182, 183, 184, 187, 190, 191, 194, 195, 198, 201, 203, 205, 206,
#        207, 208])

# %%
X_test_columns[(lasso.coef_ != 0).nonzero()[0]]
# Out:
# Index(['1st Flr SF', 'Alley_NoAlley', 'Bldg Type_Duplex', 'Bldg Type_Twnhs',
#        'Bldg Type_TwnhsE', 'Bsmt Cond', 'Bsmt Exposure', 'Bsmt Full Bath',
#        'Bsmt Qual', 'BsmtFin SF 1', 'BsmtFin SF 2', 'BsmtFin Type 1',
#        'Condition 1_Norm', 'Condition 1_PosA', 'Condition 1_PosN',
#        'Condition 1_RRAe', 'Condition 2_PosA', 'Exter Qual',
#        'Exterior 1st_BrkFace', 'Exterior 1st_CemntBd', 'Exterior 1st_HdBoard',
#        'Exterior 1st_Stucco', 'Exterior 1st_Wd Sdng', 'Exterior 2nd_HdBoard',
#        'Exterior 2nd_Stucco', 'Exterior 2nd_Wd Shng', 'Fireplace Qu',
#        'Fireplaces', 'Foundation_PConc', 'Full Bath', 'Functional',
#        'Garage Area', 'Garage Cars', 'Garage Finish', 'Garage Type_Basment',
#        'Garage Type_NoGarage', 'Gr Liv Area', 'Half Bath', 'Heating QC',
#        'Heating_OthW', 'House Style_1Story', 'House Style_SLvl',
#        'Kitchen AbvGr', 'Kitchen Qual', 'Land Contour_HLS', 'Land Contour_Low',
#        'Lot Area', 'Lot Config_CulDSac', 'MS SubClass_120', 'MS SubClass_150',
#        'MS SubClass_160', 'MS SubClass_190', 'MS SubClass_90', 'MS Zoning_FV',
#        'MS Zoning_RM', 'Mas Vnr Area', 'Mas Vnr Type_BrkFace',
#        'Mas Vnr Type_Stone', 'Misc Feature_Gar2', 'Misc Feature_Othr',
#        'Misc Feature_Shed', 'Misc Val', 'Neighborhood_BrkSide',
#        'Neighborhood_Crawfor', 'Neighborhood_Edwards', 'Neighborhood_GrnHill',
#        'Neighborhood_NAmes', 'Neighborhood_NPkVill', 'Neighborhood_NWAmes',
#        'Neighborhood_NoRidge', 'Neighborhood_NridgHt', 'Neighborhood_OldTown',
#        'Neighborhood_SawyerW', 'Neighborhood_Somerst', 'Neighborhood_StoneBr',
#        'Overall Cond', 'Overall Qual', 'Pool Area', 'Pool QC',
#        'Roof Matl_CompShg', 'Roof Matl_Membran', 'Roof Matl_WdShngl',
#        'Roof Style_Hip', 'Roof Style_Mansard', 'Sale Type_Con',
#        'Sale Type_ConLD', 'Sale Type_New', 'Screen Porch', 'TotRms AbvGrd',
#        'Utilities', 'Wood Deck SF', 'Year Built', 'Year Remod/Add'],
#       dtype='object')

# %%
lasso.coef_[(lasso.coef_ != 0).nonzero()[0]]
# Out:
# array([ 3.35479121e+03,  1.87641908e+02, -6.46246421e+00, -2.37562519e+03,
#        -3.41850928e+03, -2.21852612e+02,  4.95229523e+03,  2.66680634e+03,
#         2.00652402e+03,  4.36185112e+03,  2.99436949e+02,  1.84374717e+03,
#         2.14666156e+03,  5.50080548e+02,  1.55482443e+03, -1.90689606e+02,
#         9.44559902e+02,  6.15004049e+03,  2.30282725e+03,  1.32593541e+03,
#        -9.95310939e+02, -1.25795099e+03, -7.75721454e+02, -4.96995190e+02,
#        -6.38465968e+02, -7.94856271e+01,  2.06428799e+03,  1.69029074e+03,
#         9.69120800e+02,  1.22383718e+03,  1.95002323e+03,  1.67801821e+03,
#         4.32119610e+03,  2.83932552e+01, -4.74470672e+02,  5.64707950e+02,
#         2.10369728e+04,  3.82129906e+02,  1.23764363e+03, -5.58347211e+02,
#         2.21091357e+03, -4.22112709e+02, -1.41399133e+03,  5.91286332e+03,
#         2.63993906e+03,  1.67261264e+02,  2.57957095e+03,  1.58747297e+03,
#        -2.61750873e+03, -5.34468241e+02, -1.35379201e+03, -3.91954764e+02,
#        -3.70473109e+02,  9.12744197e+01, -7.08066330e+02,  4.12068700e+03,
#        -4.06084451e+02,  1.04342105e+01,  3.40491670e+03,  2.47229649e+03,
#         7.53190113e+02, -7.38234442e+03,  1.35019110e+02,  2.05945262e+03,
#        -1.29341743e+03,  2.91503194e+03, -1.42050489e+02,  1.76748745e+02,
#        -2.08764548e+02,  4.17521174e+03,  9.48614195e+03, -4.82393831e+02,
#        -7.02490288e+01,  2.17074254e+03,  6.41373812e+03,  3.31734881e+03,
#         1.35949620e+04,  3.69908092e+03, -2.31776737e+03,  1.05217561e+03,
#         2.99718202e+02,  2.10770026e+03,  2.03168326e+03, -1.03176108e+03,
#         9.88806724e+02,  4.48298760e+00,  3.38752544e+03,  1.90790718e+00,
#         4.06563432e+02,  1.59243489e+00,  1.79569479e+03,  4.02473911e+03,
#         8.29091365e+02])

# %%
def plot_cv():
    pass

# %% [markdown]
# **Ridge Regression**

# %%
# # Cross Validation
# ridge = RidgeCV(alphas=np.logspace(0, 5, 200))
# ridge_scores = cross_val_score(ridge, X_train, y_train, cv=10)
# ridge_scores.mean()

# %%
# Cross Validation
optimal_ridge = RidgeCV(alphas=np.logspace(0, 5, 200), cv=10)

# %%
# Model Fitting and Evaluation
optimal_ridge.fit(X_train, y_train)

ridge = Ridge(alpha=optimal_ridge.alpha_)
ridge.fit(X_train, y_train)

ridge_scores = cross_val_score(ridge, X_train, y_train, cv=10)
ridge_scores.mean()
# Out:
# 0.859181299393456

# %%
(-cross_val_score(ridge, X_train, y_train, cv=10, scoring='neg_root_mean_squared_error')).mean()
# Out:
# 28891.780973751425

# %%
y_test_pred = ridge.predict(X_test)

# %%
y_test_pred = y_test_pred.reshape(-1)

# %%
submissions = make_and_get_submissions_file(X_test_indices, y_test_pred, 'submissions_ridge_regression_all_features')

# %% [markdown]
# ## Feature Engineering

# %%
nominal_features
# Out:
# ['PID',
#  'MS SubClass',
#  'MS Zoning',
#  'Street',
#  'Alley',
#  'Land Contour',
#  'Lot Config',
#  'Neighborhood',
#  'Condition 1',
#  'Condition 2',
#  'Bldg Type',
#  'House Style',
#  'Roof Style',
#  'Roof Matl',
#  'Exterior 1st',
#  'Exterior 2nd',
#  'Mas Vnr Type',
#  'Foundation',
#  'Heating',
#  'Central Air',
#  'Garage Type',
#  'Misc Feature',
#  'Sale Type']

# %%
train_cleaned.corr()
# Out:
#                       PID  MS SubClass  Lot Frontage  Lot Area  Lot Shape  \
# PID              1.000000    -0.002672     -0.041084  0.021098   0.093914
# MS SubClass     -0.002672     1.000000     -0.213981 -0.244227   0.078192
# Lot Frontage    -0.041084    -0.213981      1.000000  0.134701   0.176135
# Lot Area         0.021098    -0.244227      0.134701  1.000000  -0.302693
# Lot Shape        0.093914     0.078192      0.176135 -0.302693   1.000000
# Utilities       -0.031663     0.023478      0.019495 -0.030260   0.013929
# Land Slope       0.116265    -0.042851     -0.008858  0.308062  -0.108466
# Overall Qual    -0.261299     0.037341      0.115350  0.108687  -0.250656
# Overall Cond     0.104360    -0.071524     -0.037078 -0.018588   0.076562
# Year Built      -0.341919     0.037946      0.020936  0.038175  -0.279387
# Year Remod/Add  -0.171070     0.046441      0.059376  0.050353  -0.222556
# Mas Vnr Area    -0.247349    -0.004452      0.103000  0.172039  -0.130889
# Exter Qual      -0.219824     0.019263      0.102988  0.090076  -0.238760
# Exter Cond       0.038906    -0.057985     -0.039017  0.020772   0.004186
# Bsmt Qual       -0.190813     0.056132      0.047284  0.071439  -0.237758
# Bsmt Cond       -0.103847    -0.022895      0.005334 -0.000062  -0.090315
# Bsmt Exposure    0.001653     0.055519      0.100282  0.201761  -0.185454
# BsmtFin Type 1  -0.115576     0.061597     -0.047459  0.047661  -0.160346
# BsmtFin SF 1    -0.089111    -0.059787      0.058840  0.218108  -0.185515
# BsmtFin Type 2  -0.023348    -0.035055      0.000632  0.025334  -0.032415
# BsmtFin SF 2    -0.015778    -0.068524      0.000989  0.043750  -0.035917
# Bsmt Unf SF     -0.108209    -0.140173      0.148630  0.045187  -0.010348
# Total Bsmt SF   -0.204366    -0.225383      0.207842  0.284708  -0.213888
# Heating QC      -0.097012    -0.024467      0.064989  0.027410  -0.162602
# Central Air     -0.200848    -0.074502     -0.002032  0.056741  -0.136111
# Electrical      -0.146030     0.005107     -0.005394  0.041718  -0.118940
#                  Year Built  ...  Enclosed Porch  3Ssn Porch  Screen Porch  \
# PID               -0.341919  ...        0.148395   -0.025357     -0.043784
# MS SubClass        0.037946  ...       -0.039068   -0.030494     -0.039820
# Lot Frontage       0.020936  ...        0.013269    0.008188      0.037053
# Lot Area           0.038175  ...        0.009339    0.020189      0.069676
# Lot Shape         -0.279387  ...        0.093187   -0.028621     -0.070657
# Utilities          0.029106  ...        0.011254    0.003083     -0.071660
# Land Slope        -0.048398  ...        0.030396    0.013910      0.047576
# Overall Qual       0.599846  ...       -0.154609    0.032959      0.051348
# Overall Cond      -0.369101  ...        0.111802    0.026540      0.046250
# Year Built         1.000000  ...       -0.380307    0.017228     -0.035339
# Year Remod/Add     0.625905  ...       -0.239266    0.041697     -0.038601
# Mas Vnr Area       0.329297  ...       -0.106724    0.011076      0.086412
# Exter Qual         0.612995  ...       -0.182121    0.047388      0.022211
# Exter Cond        -0.083146  ...        0.051117    0.012830      0.045928
# Bsmt Qual          0.622325  ...       -0.207619    0.029559      0.023369
# Bsmt Cond          0.192093  ...       -0.062480   -0.011153      0.002231
# Bsmt Exposure      0.318255  ...       -0.081755    0.008886      0.049549
# BsmtFin Type 1     0.381116  ...       -0.137765    0.032250      0.031306
# BsmtFin SF 1       0.279527  ...       -0.085037    0.048112      0.094089
# BsmtFin Type 2    -0.008430  ...        0.023571    0.003239      0.054626
# BsmtFin SF 2      -0.019128  ...        0.005083   -0.024514      0.095815
# Bsmt Unf SF        0.133916  ...       -0.008186    0.020838     -0.055203
# Total Bsmt SF      0.412331  ...       -0.093494    0.060945      0.077309
# Heating QC         0.459185  ...       -0.121105    0.035950     -0.020557
# Central Air        0.374170  ...       -0.127159    0.028273      0.052452
# Electrical         0.333046  ...       -0.147242    0.006731     -0.001707
# 1st Flr SF         0.331974  ...       -0.050056    0.068794      0.092379
# 2nd Flr SF         0.020835  ...        0.022329   -0.033221      0.035885
# Low Qual Fin SF   -0.159512  ...        0.090614   -0.003598      0.013842
# Gr Liv Area        0.261870  ...       -0.010919    0.025301      0.104516
# Bsmt Full Bath     0.217643  ...       -0.076412    0.023107      0.055752
# Bsmt Half Bath    -0.029070  ...       -0.011994    0.030289      0.036802
# Full Bath          0.480810  ...       -0.130605    0.029234     -0.011423
# Half Bath          0.279323  ...       -0.099354   -0.026702      0.049104
# Bedroom AbvGr     -0.040179  ...        0.032511   -0.034021      0.019724
# Kitchen AbvGr     -0.125632  ...        0.009497   -0.021149     -0.059282
# Kitchen Qual       0.535406  ...       -0.148127    0.028500      0.037411
# TotRms AbvGrd      0.140227  ...        0.004203   -0.008051      0.046930
# Functional         0.157293  ...       -0.048904   -0.022498     -0.016332
# Fireplaces         0.169992  ...        0.007360    0.026854      0.169038
# Fireplace Qu       0.242107  ...       -0.020192    0.049383      0.119052
# Garage Yr Blt      0.274841  ...       -0.081776    0.011449      0.060963
# Garage Finish      0.598084  ...       -0.176630    0.022445      0.048972
# Garage Cars        0.543336  ...       -0.142526    0.028946      0.055037
# Garage Area        0.488495  ...       -0.115772    0.044470      0.072394
# Garage Qual        0.301309  ...       -0.091524    0.013945      0.081564
# Garage Cond        0.285223  ...       -0.083654    0.004484      0.071939
# Paved Drive        0.450510  ...       -0.185972    0.003096      0.042113
# Wood Deck SF       0.220484  ...       -0.114937   -0.011144     -0.068744
# Open Porch SF      0.204672  ...       -0.078069   -0.006589      0.062455
# Enclosed Porch    -0.380307  ...        1.000000   -0.032351     -0.069494
# 3Ssn Porch         0.017228  ...       -0.032351    1.000000     -0.029956
# Screen Porch      -0.035339  ...       -0.069494   -0.029956      1.000000
# Pool Area         -0.035339  ...       -0.069494   -0.029956      1.000000
# Pool QC            0.010492  ...        0.008514   -0.006429      0.003542
# Fence             -0.206488  ...        0.073152   -0.008356      0.038703
# Misc Val           0.001511  ...        0.015199   -0.005001      0.006806
# Mo Sold           -0.014587  ...        0.008167    0.020540      0.030567
# Yr Sold           -0.001717  ...       -0.002994    0.019254     -0.018399
# SalePrice          0.571860  ...       -0.138048    0.049865      0.137802
#
#                  Pool Area   Pool QC     Fence  Misc Val   Mo Sold   Yr Sold  \
# PID              -0.043784  0.025042  0.086905  0.003787 -0.025925  0.008810
# MS SubClass      -0.039820 -0.007702 -0.092767 -0.027845  0.014259 -0.033441
# Lot Frontage      0.037053  0.101012 -0.011282  0.026334 -0.011753  0.010643
# Lot Area          0.069676  0.129666 -0.031270  0.095356  0.003315 -0.028218
# Lot Shape        -0.070657 -0.055686  0.045489 -0.050464 -0.001791  0.032360
# Utilities        -0.071660  0.001855  0.014238  0.002699  0.049417 -0.027701
# Land Slope        0.047576 -0.013497 -0.022696 -0.005521 -0.013711  0.015105
# Overall Qual      0.051348  0.023363 -0.173436  0.022951  0.012244 -0.008083
# Overall Cond      0.046250 -0.008878  0.172762  0.013914 -0.001235  0.046149
# Year Built       -0.035339  0.010492 -0.206488  0.001511 -0.014587 -0.001717
# Year Remod/Add   -0.038601 -0.018762 -0.182118 -0.000814  0.005454  0.045623
# Mas Vnr Area      0.086412  0.014691 -0.090414  0.079162 -0.001948 -0.018797
# Exter Qual        0.022211  0.034637 -0.233649  0.013998  0.010264  0.014922
# Exter Cond        0.045928 -0.014412  0.080895 -0.000751  0.008641  0.025960
# Bsmt Qual         0.023369  0.001064 -0.143945  0.004002  0.005134 -0.004136
# Bsmt Cond         0.002231 -0.022284  0.012818 -0.007839  0.004969 -0.031909
# Bsmt Exposure     0.049549  0.036882 -0.087970  0.002489  0.004609 -0.054841
# BsmtFin Type 1    0.031306 -0.008638 -0.002777  0.035598 -0.022641  0.053508
# BsmtFin SF 1      0.094089  0.088893  0.020255  0.130990 -0.011806  0.040732
# BsmtFin Type 2    0.054626  0.020550  0.102063  0.000117 -0.000371  0.013849
# BsmtFin SF 2      0.095815  0.033778  0.089723 -0.005751 -0.012198  0.000456
# Bsmt Unf SF      -0.055203 -0.031865 -0.144091 -0.005685  0.017373 -0.043208
# Total Bsmt SF     0.077309  0.072164 -0.088681  0.126679  0.000572 -0.000791
# Heating QC       -0.020557 -0.021457 -0.147914  0.013700  0.001056  0.002205
# Central Air       0.052452  0.017010  0.004645  0.011461 -0.039867  0.015968
# Overall Cond     -0.094233
# Year Built        0.571860
# Year Remod/Add    0.549397
# Mas Vnr Area      0.512699
# Exter Qual        0.711814
# Exter Cond        0.038380
# Bsmt Qual         0.615154
# Bsmt Cond         0.224576
# Bsmt Exposure     0.426241
# BsmtFin Type 1    0.352739
# BsmtFin SF 1      0.424380
# BsmtFin Type 2    0.018032
# BsmtFin SF 2      0.019387
# Bsmt Unf SF       0.191275
# Total Bsmt SF     0.631975
# Heating QC        0.458396
# Central Air       0.277770
# Electrical        0.246616
# 1st Flr SF        0.623523
# 2nd Flr SF        0.250946
# Low Qual Fin SF  -0.041153
# Gr Liv Area       0.699026
# Bsmt Full Bath    0.284514
# Bsmt Half Bath   -0.043856
# Full Bath         0.538471
# Half Bath         0.278486
# Bedroom AbvGr     0.138336
# Kitchen AbvGr    -0.126232
# Kitchen Qual      0.691030
# TotRms AbvGrd     0.505188
# Functional        0.126771
# Fireplaces        0.471222
# Fireplace Qu      0.537287
# Garage Yr Blt     0.258027
# Garage Finish     0.558269
# Garage Cars       0.647015
# Garage Area       0.648661
# Garage Qual       0.285413
# Garage Cond       0.264905
# Paved Drive       0.290081
# Wood Deck SF      0.328729
# Open Porch SF     0.325625
# Enclosed Porch   -0.138048
# 3Ssn Porch        0.049865
# Screen Porch      0.137802
# Pool Area         0.137802
# Pool QC           0.031275
# Fence            -0.155390
# Misc Val         -0.006787
# Mo Sold           0.026208
# Yr Sold          -0.011046
# SalePrice         1.000000
#
# [60 rows x 60 columns]

# %%
len(set(nominal_features).difference(set(train_cleaned.corr().columns)))
# Out:
# 20

# %%
set(nominal_features).difference(set(train_cleaned.corr().columns))
# Out:
# {'Alley',
#  'Bldg Type',
#  'Condition 1',
#  'Condition 2',
#  'Exterior 1st',
#  'Exterior 2nd',
#  'Foundation',
#  'Garage Type',
#  'Heating',
#  'House Style',
#  'Land Contour',
#  'Lot Config',
#  'MS Zoning',
#  'Mas Vnr Type',
#  'Misc Feature',
#  'Neighborhood',
#  'Roof Matl',
#  'Roof Style',
#  'Sale Type',
#  'Street'}

# %%
train_cleaned[sorted(nominal_features)].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2026 entries, 109 to 10
# Data columns (total 23 columns):
# Alley           2026 non-null object
# Bldg Type       2026 non-null object
# Central Air     2026 non-null int64
# Condition 1     2026 non-null object
# Condition 2     2026 non-null object
# Exterior 1st    2026 non-null object
# Exterior 2nd    2026 non-null object
# Foundation      2026 non-null object
# Garage Type     2026 non-null object
# Heating         2026 non-null object
# House Style     2026 non-null object
# Land Contour    2026 non-null object
# Lot Config      2026 non-null object
# MS SubClass     2026 non-null int64
# MS Zoning       2026 non-null object
# Mas Vnr Type    2026 non-null object
# Misc Feature    2026 non-null object
# Neighborhood    2026 non-null object
# PID             2026 non-null int64
# Roof Matl       2026 non-null object
# Roof Style      2026 non-null object
# Sale Type       2026 non-null object
# Street          2026 non-null object
# dtypes: int64(3), object(20)
# memory usage: 379.9+ KB

# %%
plt.figure(figsize=(15,15))
sns.heatmap(train_cleaned.corr(), annot=False, cmap='coolwarm')

# %%
submissions.shape
# Out:
# (879, 1)
